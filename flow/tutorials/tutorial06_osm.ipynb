# %% [markdown]
# # Tutorial 06: Networks from OpenStreetMap
#
# In this tutorial, we discuss how networks that have been imported from OpenStreetMap can be integrated and run in Flow. This will all be presented via the Bay Bridge network, seen in the figure below. Networks from OpenStreetMap are commonly used in many traffic simulators for the purposes of replicating traffic in realistic traffic geometries. This is true in both SUMO and Aimsun (which are both supported in Flow), with each supporting several techniques for importing such network files. This process is further simplified and abstracted in Flow, with users simply required to specify the path to the osm file in order to simulate traffic in the network.
#
#
# <img src="img/bay_bridge_osm.png" width=750>
# <center> **Figure 1**: Snapshot of the Bay Bridge from OpenStreetMap </center>
#
# Before we begin, let us import all relevant Flow parameters as we have done for previous tutorials. If you are unfamiliar with these parameters, you are encouraged to review tutorial 1.

# %%
# the TestEnv environment is used to simply simulate the network
from flow.envs import TestEnv

# the Experiment class is used for running simulations
from flow.core.experiment import Experiment

# all other imports are standard
from flow.core.params import VehicleParams
from flow.core.params import NetParams
from flow.core.params import InitialConfig
from flow.core.params import EnvParams
from flow.core.params import SumoParams

# %% [markdown]
# ## 1. Running a Default Simulation
#
# In order to create a network object in Flow with network features depicted from OpenStreetMap, we will use the base `Network` class. This class can sufficiently support the generation of any .osm file.

# %%
from flow.networks import Network

# %% [markdown]
# In order to recreate the network features of a specific osm file, the path to the osm file must be specified in `NetParams`. For this example, we will use an osm file extracted from the section of the Bay Bridge as depicted in Figure 1.
#
# In order to specify the path to the osm file, simply fill in the `osm_path` attribute with the path to the .osm file as follows:

# %%
net_params = NetParams(
    osm_path='networks/bay_bridge.osm'
)

# %% [markdown]
# Next, we create all other parameters as we have in tutorials 1 and 2. For this example, we will assume a total of 1000 are uniformly spread across the Bay Bridge. Once again, if the choice of parameters is unclear, you are encouraged to review Tutorial 1.

# %%
# create the remainding parameters
env_params = EnvParams()
sim_params = SumoParams(render=True)
initial_config = InitialConfig()
vehicles = VehicleParams()
vehicles.add('human', num_vehicles=100)

# %% [markdown]
# We are finally ready to test our network in simulation. In order to do so, we create an `Experiment` object and run the simulation for a number of steps. This is done in the cell below.

# %%
flow_params = dict(
    exp_tag='bay_bridge',
    env_name=TestEnv,
    network=Network,
    simulator='traci',
    sim=sim_params,
    env=env_params,
    net=net_params,
    veh=vehicles,
    initial=initial_config,
)

# number of time steps
flow_params['env'].horizon = 1000
exp = Experiment(flow_params)

# run the sumo simulation
_ = exp.run(1)
# Out:
# Warning: The referenced geometry information (ref='2387017057') is not known
# Warning: The referenced geometry information (ref='30366147') is not known
# Warning: The referenced geometry information (ref='2387017072') is not known
# Warning: The referenced geometry information (ref='2387017027') is not known
# Warning: The referenced geometry information (ref='30366151') is not known
# Warning: The referenced geometry information (ref='669581335') is not known
# Warning: The referenced geometry information (ref='30364622') is not known
# Warning: The referenced geometry information (ref='53021715') is not known
# Warning: The referenced geometry information (ref='53030881') is not known
# Warning: The referenced geometry information (ref='53033904') is not known
# Warning: The referenced geometry information (ref='53036391') is not known
# Warning: The referenced geometry information (ref='53047657') is not known
# Warning: The referenced geometry information (ref='1237941535') is not known
# Warning: The referenced geometry information (ref='1237941419') is not known
# Warning: The referenced geometry information (ref='371039233') is not known
# Warning: The referenced geometry information (ref='371041051') is not known
# Warning: The referenced geometry information (ref='371041052') is not known
# Warning: The referenced geometry information (ref='371041051') is not known
# Warning: The referenced geometry information (ref='371041696') is not known
# Warning: The referenced geometry information (ref='371041051') is not known
# Warning: The referenced geometry information (ref='371041696') is not known
# Warning: The referenced geometry information (ref='373353052') is not known
# Warning: The referenced geometry information (ref='373356395') is not known
# Warning: The referenced geometry information (ref='373356398') is not known
# ...
# Warning: Speed of straight connection '-6374818#1_0->6376011#0_0' reduced by 12.77 due to turning radius of 16.25 (length=5.50 angle=35.42)
# Warning: Speed of straight connection '-6374818#1_0->-6374818#0_0' reduced by 13.91 due to turning radius of 12.56 (length=5.86 angle=43.58)
# Warning: Speed of straight connection '6374818#0_0->6374818#1_0' reduced by 15.20 due to turning radius of 8.96 (length=4.07 angle=43.58)
# Warning: Speed of straight connection '107414305#1_0->107414306#1_0' reduced by 12.89 due to turning radius of 15.83 (length=5.22 angle=34.88)
# Warning: Speed of straight connection '107414306#0_0->107414306#1_0' reduced by 13.80 due to turning radius of 12.90 (length=5.78 angle=42.35)
# Warning: Speed of straight connection '-107414306#1_0->-107414306#0_0' reduced by 14.89 due to turning radius of 9.76 (length=4.28 angle=42.35)
# Warning: Speed of straight connection '91181773#2_0->225719777_0' reduced by 11.96 due to turning radius of 30.91 (length=19.92 angle=52.89)
# Warning: Intersecting left turns at junction '2304502490' from lane '202455432#2_0' and lane '-202455432#3_0'. (increase junction radius to avoid this)
# Warning: Speed of straight connection '6331516#2_0->6331516#3_0' reduced by 7.55 due to turning radius of 7.30 (length=2.59 angle=37.82)
# Warning: Speed of straight connection '-236741611_0->-131782321_0' reduced by 6.37 due to turning radius of 10.29 (length=2.59 angle=30.66)
# Warning: Speed of straight connection '27397715#2_0->32931798#0_0' reduced by 10.56 due to turning radius of 53.92 (length=15.24 angle=31.44)
# Warning: Speed of straight connection '27397715#2_1->32931798#0_1' reduced by 9.64 due to turning radius of 59.80 (length=16.93 angle=31.44)
# Warning: Speed of turning connection '417101722#1_1->32931798#0_1' reduced by 23.10 due to turning radius of 3.99 (length=6.61 angle=133.95)
# Warning: Speed of straight connection '104441120#5_0->107414305#0_0' reduced by 11.32 due to turning radius of 21.62 (length=1.69 angle=19.66)
# Warning: Speed of turning connection '8922560#0_1->417101703_1' reduced by 24.26 due to turning radius of 2.26 (length=2.95 angle=131.15)
# Warning: Speed of turning connection '393645070_2->11194044_1' reduced by 22.15 due to turning radius of 5.76 (length=6.49 angle=90.05)
# Warning: Speed of turning connection '393645065_1->393645070_2' reduced by 22.01 due to turning radius of 6.06 (length=6.68 angle=87.76)
# Warning: Speed of straight connection '-88559661_0->28842183_0' reduced by 19.90 due to turning radius of 11.29 (length=6.41 angle=50.04)
# Warning: Speed of straight connection '-88559661_0->28842183_1' reduced by 19.37 due to turning radius of 12.86 (length=7.38 angle=50.04)
# Warning: Speed of straight connection '28842183_0->-406944763_0' reduced by 6.34 due to turning radius of 31.39 (length=13.19 angle=39.70)
# Warning: Speed of straight connection '29328570#4_0->88463826#1_1' reduced by 9.90 due to turning radius of 11.39 (length=9.68 angle=67.38)
# Warning: Speed of straight connection '29328570#4_0->88463826#1_2' reduced by 10.75 due to turning radius of 9.08 (length=7.57 angle=67.38)
# Warning: Speed of straight connection '417101722#0_0->417101722#1_0' reduced by 21.54 due to turning radius of 7.07 (length=2.78 angle=40.42)
# Warning: Speed of straight connection '472264462#0_0->472264462#1_0' reduced by 12.76 due to turning radius of 9.83 (length=1.73 angle=25.99)
# Warning: Speed of turning connection '202455451#1_1->393667838_1' reduced by 22.49 due to turning radius of 5.08 (length=8.95 angle=134.81)
# Warning: Speed of turning connection '202455451#1_1->393667838_2' reduced by 23.82 due to turning radius of 2.85 (length=4.28 angle=134.81)
# Warning: Speed of straight connection '37395881#0_0->37395881#1_0' reduced by 8.29 due to turning radius of 9.83 (length=2.74 angle=32.41)
# Warning: Speed of straight connection '443104962#0_0->443104962#1_0' reduced by 6.04 due to turning radius of 11.19 (length=2.37 angle=28.07)
# Warning: Intersecting left turns at junction '442375151' from lane '47386657#1_0' and lane '-47386657#2_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '442375151' from lane '37721154#2_0' and lane '357553250_0'. (increase junction radius to avoid this)
# Warning: Speed of straight connection '393789561#0_0->393789561#1_0' reduced by 17.60 due to turning radius of 18.85 (length=50.47 angle=175.22)
# Warning: Speed of straight connection '393789561#0_1->393789561#1_1' reduced by 23.15 due to turning radius of 3.90 (length=8.76 angle=176.78)
# Warning: Speed of straight connection '393789561#0_2->393789561#1_2' reduced by 24.57 due to turning radius of 1.87 (length=3.06 angle=178.43)
# Warning: Speed of straight connection '468201422#1_0->514170580_0' reduced by 11.35 due to turning radius of 12.00 (length=12.26 angle=77.73)
# Warning: Speed of straight connection '468201422#1_1->514170580_1' reduced by 9.86 due to turning radius of 16.84 (length=13.39 angle=62.85)
# Warning: Speed of straight connection '507471558#1_0->507471558#2_0' reduced by 6.59 due to turning radius of 9.68 (length=2.80 angle=33.05)
# Warning: Speed of turning connection '224199014#0_1->224199014#1_1' reduced by 22.52 due to turning radius of 5.03 (length=3.60 angle=63.74)
# Warning: Speed of turning connection '224199014#0_1->513729744_0' reduced by 23.01 due to turning radius of 4.14 (length=5.44 angle=108.30)
# Warning: Speed of turning connection '224199014#0_1->513729744_1' reduced by 24.32 due to turning radius of 2.17 (length=2.24 angle=108.30)
# Warning: Speed of straight connection '-6328946#1_0->517503395_0' reduced by 6.78 due to turning radius of 17.88 (length=7.72 angle=40.90)
# Warning: Intersecting left turns at junction '53006266' from lane '6345099#1_0' and lane '-6324663#0_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53030270' from lane '6330425#0_0' and lane '-6330425#1_0'. (increase junction radius to avoid this)
# Warning: Speed of straight connection '-6380082_0->476007028_0' reduced by 9.75 due to turning radius of 28.29 (length=18.06 angle=52.64)
# Warning: Speed of straight connection '-476007028_0->6380082_0' reduced by 10.53 due to turning radius of 24.84 (length=15.80 angle=52.64)
# Warning: Speed of turning connection '393667838_2->28413803#0_1' reduced by 23.31 due to turning radius of 3.64 (length=6.76 angle=151.39)
# Warning: Speed of turning connection '517553650_1->416160396_1' reduced by 25.16 due to turning radius of 1.25 (length=1.09 angle=154.20)
# Warning: Speed of straight connection '202455452#1_0->37393956_0' reduced by 8.19 due to turning radius of 69.75 (length=15.44 angle=27.83)
# Warning: Speed of turning connection '415879140_1->37393956_1' reduced by 23.79 due to turning radius of 2.90 (length=6.02 angle=179.52)
# Warning: Intersecting left turns at junction '53061136' from lane '25759170#0_0' and lane '-25759170#1_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53061136' from lane '6340506#12_0' and lane '-6340506#13_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53064021' from lane '6387456#0_0' and lane '-6387456#1_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53081147' from lane '6348893#8_0' and lane '-6348893#9_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53086503' from lane '6348893#5_0' and lane '-6348893#6_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53090250' from lane '202455430#3_1' and lane '-202455430#4_1'. (increase junction radius to avoid this)
# Warning: Speed of straight connection '107414306#1_0->107414306#2_0' reduced by 5.69 due to turning radius of 49.66 (length=17.83 angle=35.91)
# Warning: Intersecting left turns at junction '53093233' from lane '6406221#4_0' and lane '-6406221#5_0'. (increase junction radius to avoid this)
# Warning: Speed of straight connection '-107414306#2_0->-107414306#1_0' reduced by 6.61 due to turning radius of 44.31 (length=15.88 angle=35.91)
# Warning: Intersecting left turns at junction '53097554' from lane '6387456#2_0' and lane '-6387456#3_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53101588' from lane '6361117#8_0' and lane '-6361117#9_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53101588' from lane '11185522#1_0' and lane '-11185522#2_0'. (increase junction radius to avoid this)
# Warning: Speed of straight connection '6369257_0->11196785#0_0' reduced by 7.02 due to turning radius of 8.59 (length=3.41 angle=40.10)
# Warning: Speed of straight connection '-11196785#0_0->-6369257_0' reduced by 9.57 due to turning radius of 3.40 (length=1.14 angle=40.10)
# Warning: Speed of straight connection '-107414312#0_0->-6374818#1_0' reduced by 5.63 due to turning radius of 50.07 (length=17.81 angle=35.71)
# Warning: Speed of straight connection '6374818#1_0->107414312#0_0' reduced by 6.54 due to turning radius of 44.70 (length=15.87 angle=35.71)
# Warning: Intersecting left turns at junction '53118311' from lane '6374818#1_0' and lane '-107414312#0_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '53143038' from lane '11195889#6_0' and lane '-174701214#0_0'. (increase junction radius to avoid this)
# Warning: Intersecting left turns at junction '65302674' from lane '8916727_0' and lane '-8919923_0'. (increase junction radius to avoid this)
# Warning: Speed of straight connection '236578411_0->8917719#0_0' reduced by 5.19 due to turning radius of 13.78 (length=2.01 angle=23.89)
# Warning: Speed of turning connection '-88559691#0_0->-88572877#5_0' reduced by 23.88 due to turning radius of 2.77 (length=2.58 angle=89.92)
# Warning: Speed of straight connection '224316513_0->417099324_0' reduced by 6.07 due to turning radius of 38.34 (length=12.68 angle=34.36)
# Warning: Speed of straight connection '224316513_1->417099324_1' reduced by 5.07 due to turning radius of 43.85 (length=14.55 angle=34.36)
# Warning: Speed of straight connection '397269728#1_0->91181773#0_0' reduced by 10.70 due to turning radius of 53.06 (length=17.88 angle=34.60)
# Warning: Speed of straight connection '397269728#1_1->91181773#0_1' reduced by 9.80 due to turning radius of 58.76 (length=19.83 angle=34.60)
# Warning: Speed of straight connection '-8917758#2_0->-8917758#1_0' reduced by 5.40 due to turning radius of 13.12 (length=2.08 angle=24.68)
# Warning: Speed of straight connection '32931798#3_0->27146036#0_0' reduced by 8.58 due to turning radius of 67.05 (length=11.09 angle=24.59)
# Warning: Speed of straight connection '32931798#3_1->27146036#0_1' reduced by 7.43 due to turning radius of 75.29 (length=12.47 angle=24.59)
# Warning: Speed of turning connection '32931798#3_1->8922560#0_1' reduced by 24.28 due to turning radius of 2.22 (length=2.65 angle=121.62)
# Warning: Speed of straight connection '-43100047#3_0->-43100047#2_0' reduced by 6.59 due to turning radius of 9.68 (length=2.80 angle=33.06)
# Warning: Speed of straight connection '-427286187#6_0->-427286187#5_0' reduced by 12.10 due to turning radius of 18.62 (length=1.73 angle=20.57)
# Warning: Speed of straight connection '-8920256#1_0->-8920256#0_0' reduced by 8.59 due to turning radius of 33.78 (length=11.72 angle=35.36)
# Warning: Speed of straight connection '8920256#0_0->8920256#1_0' reduced by 7.54 due to turning radius of 39.17 (length=13.63 angle=35.36)
# Warning: Speed of straight connection '456140296#1_0->8920389_0' reduced by 6.23 due to turning radius of 10.66 (length=2.49 angle=29.49)
# Warning: Speed of turning connection '417101703_1->32931798#3_1' reduced by 24.01 due to turning radius of 2.58 (length=2.87 angle=107.23)
# Warning: Speed of straight connection '-427286187#2_0->-427286187#1_0' reduced by 13.18 due to turning radius of 14.87 (length=1.92 angle=22.83)
# Warning: Speed of turning connection '393789561#1_0->202455448_0' reduced by 22.42 due to turning radius of 5.22 (length=12.26 angle=173.94)
# Warning: Speed of straight connection '-52869884#0_0->6330963#0_0' reduced by 6.94 due to turning radius of 42.45 (length=14.70 angle=35.22)
# Warning: Speed of turning connection '28413803#0_1->202455451#1_1' reduced by 22.69 due to turning radius of 4.70 (length=4.00 angle=73.80)
# Success.
# Error during start: Traceback (most recent call last):
#   File "/home/rohanpaleja/PycharmProjects/ICCT/flow/flow/core/kernel/simulation/traci.py", line 251, in start_simulation
#     traci_connection.setOrder(0)
#   File "/home/rohanpaleja/sumo/tools/traci/connection.py", line 348, in setOrder
#     self._sendExact()
#   File "/home/rohanpaleja/sumo/tools/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
#
# Error during teardown: [Errno 3] No such process
# Error during start: Traceback (most recent call last):
#   File "/home/rohanpaleja/PycharmProjects/ICCT/flow/flow/core/kernel/simulation/traci.py", line 251, in start_simulation
#     traci_connection.setOrder(0)
#   File "/home/rohanpaleja/sumo/tools/traci/connection.py", line 348, in setOrder
#     self._sendExact()
#   File "/home/rohanpaleja/sumo/tools/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
#
# Error during teardown: [Errno 3] No such process
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14994/1959285633.py in <module>
#      16
#      17 # run the sumo simulation
# ---> 18 _ = exp.run(1)
#
# ~/PycharmProjects/ICCT/flow/flow/core/experiment.py in run(self, num_runs, rl_actions, convert_to_csv)
#     140             vel = []
#     141             custom_vals = {key: [] for key in self.custom_callables.keys()}
# --> 142             state = self.env.reset()
#     143             for j in range(num_steps):
#     144                 t0 = time.time()
#
# ~/PycharmProjects/ICCT/flow/flow/envs/base.py in reset(self)
#     436             self.sim_params.render = True
#     437             # got to restart the simulation to make it actually display anything
# --> 438             self.restart_simulation(self.sim_params)
#     439
#     440         # warn about not using restart_instance when using inflows
#
# ~/PycharmProjects/ICCT/flow/flow/envs/base.py in restart_simulation(self, sim_params, render)
#     262         self.k.vehicle.initialize(deepcopy(self.network.vehicles))
#     263         kernel_api = self.k.simulation.start_simulation(
# --> 264             network=self.k.network, sim_params=self.sim_params)
#     265         self.k.pass_api(kernel_api)
#     266
#
# ~/PycharmProjects/ICCT/flow/flow/core/kernel/simulation/traci.py in start_simulation(self, network, sim_params)
#     249
#     250                 traci_connection = traci.connect(port, numRetries=100)
# --> 251                 traci_connection.setOrder(0)
#     252                 traci_connection.simulationStep()
#     253
#
# ~/sumo/tools/traci/connection.py in setOrder(self, order)
#     346         self._queue.append(tc.CMD_SETORDER)
#     347         self._string += struct.pack("!BBi", 1 + 1 + 4, tc.CMD_SETORDER, order)
# --> 348         self._sendExact()
#     349
#     350     def close(self, wait=True):
#
# ~/sumo/tools/traci/connection.py in _sendExact(self)
#      93             length = struct.pack("!i", len(self._string) + 4)
#      94             self._socket.send(length + self._string)
# ---> 95             result = self._recvExact()
#      96         if not result:
#      97             self._socket.close()
#
# ~/sumo/tools/traci/connection.py in _recvExact(self)
#      72             result = bytes()
#      73             while len(result) < 4:
# ---> 74                 t = self._socket.recv(4 - len(result))
#      75                 if not t:
#      76                     return None
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. Customizing the Network
#
# While the above example does allow you to view the network within Flow, the simulation is limited for two reasons. For one, vehicles are placed on all edges within the network; if we wished to simulate traffic solely on the on the bridge and do not care about the artireols, for instance, this would result in unnecessary computational burdens. Next, as you may have noticed if you ran the above example to completion, routes in the base network class are defaulted to consist of the vehicles' current edges only, meaning that vehicles exit the network as soon as they reach the end of the edge they are originated on. In the next subsections, we discuss how the network can be modified to resolve these issues.
#
# ### 2.1 Specifying Traversable Edges
#
# In order to limit the edges vehicles are placed on to the road sections edges corresponding to the westbound Bay Bridge, we define an `EDGES_DISTRIBUTION` variable. This variable specifies the names of the edges within the network that vehicles are permitted to originated in, and is assigned to the network via the `edges_distribution` component of the `InitialConfig` input parameter, as seen in the code snippet below. Note that the names of the edges can be identified from the .osm file or by right clicking on specific edges from the SUMO gui (see the figure below).
#
# <img src="img/osm_edge_name.png" width=600>
# <center> **Figure 2**: Name of an edge from SUMO </center>

# %%
# we define an EDGES_DISTRIBUTION variable with the edges within 
# the westbound Bay Bridge 
EDGES_DISTRIBUTION = [
    "11197898",
    "123741311", 
    "123741303",
    "90077193#0",
    "90077193#1", 
    "340686922", 
    "236348366", 
    "340686911#0",
    "340686911#1",
    "340686911#2",
    "340686911#3",
    "236348361", 
    "236348360#0", 
    "236348360#1"
]

# the above variable is added to initial_config
new_initial_config = InitialConfig(
    edges_distribution=EDGES_DISTRIBUTION
)

# %% [markdown]
# ### 2.2 Creating Custom Routes
#
# Next, we choose to specify the routes of vehicles so that they can traverse the entire Bay Bridge, instead of the only the edge they are currently on. In order to this, we create a new network class that inherits all its properties from `Network` and simply redefine the routes by modifying the `specify_routes` variable. This method was originally introduced in Tutorial 07: Creating Custom Network. The new network class looks as follows:

# %%
# we create a new network class to specify the expected routes
class BayBridgeOSMNetwork(Network):

    def specify_routes(self, net_params):
        return {
            "11197898": [
                "11197898", "123741311", "123741303", "90077193#0", "90077193#1", 
                "340686922", "236348366", "340686911#0", "340686911#1",
                "340686911#2", "340686911#3", "236348361", "236348360#0", "236348360#1",
            ],
            "123741311": [
                "123741311", "123741303", "90077193#0", "90077193#1", "340686922", 
                "236348366", "340686911#0", "340686911#1", "340686911#2",
                "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "123741303": [
                "123741303", "90077193#0", "90077193#1", "340686922", "236348366",
                "340686911#0", "340686911#1", "340686911#2", "340686911#3", "236348361",
                "236348360#0", "236348360#1"
            ],
            "90077193#0": [
                "90077193#0", "90077193#1", "340686922", "236348366", "340686911#0",
                "340686911#1", "340686911#2", "340686911#3", "236348361", "236348360#0",
                "236348360#1"
            ],
            "90077193#1": [
                "90077193#1", "340686922", "236348366", "340686911#0", "340686911#1",
                "340686911#2", "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "340686922": [
                "340686922", "236348366", "340686911#0", "340686911#1", "340686911#2",
                "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "236348366": [
                "236348366", "340686911#0", "340686911#1", "340686911#2", "340686911#3",
                "236348361", "236348360#0", "236348360#1"
            ],
            "340686911#0": [
                "340686911#0", "340686911#1", "340686911#2", "340686911#3", "236348361",
                "236348360#0", "236348360#1"
            ],
            "340686911#1": [
                "340686911#1", "340686911#2", "340686911#3", "236348361", "236348360#0",
                "236348360#1"
            ],
            "340686911#2": [
                "340686911#2", "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "340686911#3": [
                "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "236348361": [
                "236348361", "236348360#0", "236348360#1"
            ],
            "236348360#0": [
                "236348360#0", "236348360#1"
            ],
            "236348360#1": [
                "236348360#1"
            ]
        }

# %% [markdown]
# ### 2.3 Rerunning the Simulation
#
# We are now ready to rerun the simulation with fully defined vehicle routes and a limited number of traversable edges. If we run the cell below, we can see the new simulation in action.

# %%
flow_params = dict(
    exp_tag='bay_bridge',
    env_name=TestEnv,
    network=BayBridgeOSMNetwork,
    simulator='traci',
    sim=sim_params,
    env=env_params,
    net=net_params,
    veh=vehicles,
    initial=new_initial_config,
)

# number of time steps
flow_params['env'].horizon = 10000
exp = Experiment(flow_params)

# run the sumo simulation
_ = exp.run(1)

# %% [markdown]
# ## 3. Other Tips
#
# This tutorial introduces how to incorporate OpenStreetMap files in Flow. This feature, however, does not negate other features that are introduced in other tutorials and documentation. For example, if you would like to not have vehicles be originated side-by-side within a network, this can still be done by specifying a "random" spacing for vehicles as follows:
#
#     initial_config = InitialConfig(
#         spacing="random",
#         edges_distribution=EDGES_DISTRIBUTION
#     )
#
# In addition, inflows of vehicles can be added to networks imported from OpenStreetMap as they are for any other network (see the tutorial on adding inflows for more on this).
